# %%
# %cd ../
# Out:
# /u02/bear/plasma

# %%
import numpy as np
import plasma.storages as pst

# %%
# store = pst.TensorStorage.construct('.data/zarr', np.float32, [[100, 120], [315]], 1000, 10, 30, 3)
# store

# %%
store = pst.TensorStorage('.data/zarr', [[100, 120], [315]])

# %%
# store[:100] = np.random.rand(100, 100, 120), np.random.rand(100, 315)

# %%
a, b = store[[25, 26, 27]]

# %%
a.shape, b.shape
# Out:
# ((3, 100, 120), (3, 315))
