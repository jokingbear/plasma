# %%
# %cd ../
# Out:
# /u02/thanh/workplace/plasma

# %%
from plasma.data_model.graph import DiGraph

# %%
g = DiGraph()

# %%
g.add_node(1, type=int, data={'a': 1})
g.add_node(2, type=int, data={'a': 2})
g.add_node(3, type=int, data={'a': 3})

# %%
g.add_edges_from([(1, 2), (2, 3)])

# %%
[*g.inquirer.nodes(int).select('a')]
# Out:
# [(1, 1), (2, 2), (3, 3)]

# %%
[*g.inquirer.nodes(int).select(a='a', b=lambda x,y,z: z.a + 8).filter(lambda n,td: td.a < 3).node_ids()]
# Out:
# [1, 2]
