# %%
# %cd ../
# Out:
# /u02/thanh/workplace/plasma

# %%
import plasma.logging as plogging

# %%
@plogging.Timer()
def test(x=8):
    print(x)

# %%
test(x=9)
# Out:
# 9
# TimeIO(test, [start=2025-12-23 03:49:28.495904, end=2025-12-23 03:49:28.495936, duration=0:00:00.000032], args=, kwargs=x)
