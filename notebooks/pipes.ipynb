# %%
# %cd ..
# Out:
# /u02/thanh/workplace/plasma

# %%
import plasma.functional as F

# %%
class Test(F.AutoPipe):
    
    def __init__(self, x):
        super().__init__()
        self.x = x

    def run(self, x:list[int], y:int, z=8, *args, **kwargs) -> list:
        return x + y

# %%
a = Test(Test(Test(5)))
a
# Out:
# Test[(x:list, y:int, z:Any=int, *args:Any, **kwargs:Any)->list](
#   x=Test[(x:list, y:int, z:Any=int, *args:Any, **kwargs:Any)->list](
#     x=Test[(x:list, y:int, z:Any=int, *args:Any, **kwargs:Any)->list](
#       x=5,
#     ),
#   ),
# )

# %%
F.Wrapper(Test(8))
# Out:
# Wrapper(*meta, Test(x:list, y:int, z:Any=int, *args:Any, **kwargs:Any))->tuple[*meta, list]
