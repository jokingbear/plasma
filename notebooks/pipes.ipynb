# %%
# %cd ..
# Out:
# /u02/thanh/workplace/plasma

# %%
import plasma.functional as F

# %%
class Test(F.AutoPipe):
    
    def __init__(self, x):
        super().__init__()
        self.x = x

    def run(self, x:list[int], y:int, z=8, *args, **kwargs) -> list:
        return x + y

# %%
a = Test(Test(Test(5)))
a
# Out:
# Test[(x:list, y:int, z=int, *args, **kwargs)->list](
#   x=Test[(x:list, y:int, z=int, *args, **kwargs)->list](
#     x=Test[(x:list, y:int, z=int, *args, **kwargs)->list](
#       x=5,
#     ),
#   ),
# )

# %%
F.Wrapper(Test(8))
# Out:
# Wrapper(*meta, Test(x:list, y:int, z=int, *args, **kwargs))->tuple[*meta, list]

# %%
F.auto_map(print)
# Out:
# print[automap[*args, sep=str, end=str, file=NoneType, flush=bool]] -> Any

# %%
F.chain(print, print, a)
# Out:
# print(*args, sep=str, end=str, file=NoneType, flush=bool) -> Any
#    |->print(*args, sep=str, end=str, file=NoneType, flush=bool) -> Any
#       |->Test.run(x:list, y:int, z=int, *args, **kwargs) -> list
