# %%
# %cd ..
# Out:
# /u02/thanh/workplace/plasma

# %%
import plasma.functional as F

# %%
class Test(F.AutoPipe):
    
    def __init__(self, x):
        super().__init__()
        self.x = x

    def run(self, x:list[int], y:int) -> list:
        return x * 2

# %%
a = Test(5)
a
# Out:
# Test(
#   x=5,
# ):F[[x:list, y:int], list]
