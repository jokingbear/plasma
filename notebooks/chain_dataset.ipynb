# %%
# %cd ../
# Out:
# /u02/thanh/workplace/plasma

# %%
import numpy as np
import plasma.torch.data as ptdata

# %%
a = np.arange(100)
b = 1000 + np.arange(100)

# %%
c = ptdata.ChainDataset(
    ptdata.AdhocData(a, lambda x:x),
    ptdata.AdhocData(b, lambda x:x)
)
c

# %%
c[0]
# Out:
# np.int64(0)

# %%
c[99]
# Out:
# np.int64(99)

# %%
c[192]
# Out:
# np.int64(1092)
