# %%
# %cd ../
# Out:
# /u02/thanh/workplace/plasma

# %%
import plasma.functional as F

# %%
class A(F.ReadableClass):
    
    def __init__(self):
        super().__init__()
        
        self.a1 = 8
        self.a2 = 9
        self.a3 = [1, 2, 3, 4]
        self.a3 = 'adfadf'
        self.a5 = 1, 2, 3, 4

# %%
class B(F.ReadableClass):
    
    def __init__(self):
        super().__init__()
        
        self.b1 = A()
        self.b2 = A()
        self.b3 = [A(), A()]

# %%
A()
# Out:
# A(
#   a1=8,
#   a2=9,
#   a3='adfadf',
#   a5=(1, 2, 3, 4),
# )

# %%
B()
# Out:
# B(
#   b1=A(
#     a1=8,
#     a2=9,
#     a3='adfadf',
#     a5=(1, 2, 3, 4),
#   ),
#   b2=A(
#     a1=8,
#     a2=9,
#     a3='adfadf',
#     a5=(1, 2, 3, 4),
#   ),
#   b3=[A(
#     a1=8,
#     a2=9,
#     a3='adfadf',
#     a5=(1, 2, 3, 4),
#   ), A(
#     a1=8,
#     a2=9,
#     a3='adfadf',
#     a5=(1, 2, 3, 4),
#   )],
# )
