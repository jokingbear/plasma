# %%
# %cd ../

# %%
from plasma.storages import SqlStorage

# %%
storage = SqlStorage('.test.sqlite')

# %%
statement = storage.statement('''
    CREATE TABLE IF NOT EXISTS Test (
        t INT,
        t1 INT
    )
''')
statement

# %%
storage.execute(statement)

# %%
statement = storage.statement('''
    SELECT * FROM Test
''')
statement

# %%
storage.execute(statement)
