# %%
# %cd ../

# %%
import plasma.storages as pst

# %%
store = pst.SqliteStorage('test.db')

# %%
store.connection
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 store.connection
#
# NameError: name 'store' is not defined
