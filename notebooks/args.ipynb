# %%
# %cd ../
# Out:
# /u02/thanh/workplace/plasma

# %%
import plasma.meta.object_graph as pmo

# %%
class Args(pmo.Inputs):
    a:int
    b:int
    c:pmo.Initiable

# %%
@Args.c
def hehe(a:Args):
    return a.a + a.b

# %%
inputs = Args({
    'a': 10,
    'b': 9
})
inputs
# Out:
# {
#     a: 10,
#     b: 9,
#     c: 19,
# }
